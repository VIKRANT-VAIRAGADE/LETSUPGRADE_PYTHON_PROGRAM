# %%
pip install emails
# Out:
# ...
#      |████████████████████████████████| 61kB 5.1MB/s
# ...
#      |████████████████████████████████| 409kB 6.8MB/s
# ...

# %%
import emails
message = emails.html(html = '''<p>Lets try letsupgrade.</p>
  <p><br></p>
  <p>It is one of the best edutech startup</p>''',
  subject="emil from python ",
  mail_from=('captian', 'contact.practise.v@gmail.com')
  )

# %%
mail_vai_python = message.send(to='popaj71091@95ta.com', smtp={'host': 'smtp.gmail.com', 'timeout': 5,'port':587,
                                          'user':'contact.practise.v@gmail.com','password':'Babankaka@123','tls':True})

# %%
mail_vai_python.status_code
# Out:
# 250
